# %%
from IPython.core.display import HTML

with open('creative_commons.txt', 'r') as f:
    html = f.read()
    
with open('./styles/custom.css', 'r') as f:
    styles = f.read()
    
HTML(styles)

name = '2014-08-03-first_post'

html = """
<small>
<p> This post was written as an IPython notebook.  It is available for
<a href="http://WeiChengLiou.github.com/blog/downloads/
notebooks/%s.ipynb">download</a>.</p>
<p></p>
# %s """ % (name, html)

hidecode="""
<script type="text/javascript">
function hideElements(elements, start) {
    for(var i = 0, length = elements.length; i < length;i++) {
        if(i >= start) {
            elements[i].style.display = "none";
        }
    }
}
var input_elements = document.getElementsByClassName('input');
hideElements(input_elements, 0);
var prompt_elements = document.getElementsByClassName('prompt');
hideElements(prompt_elements, 0);
</script>
"""

# %%
output_path='../repository'
urlpath='http://weichengliou.github.io/repository'
output_path='output'
urlpath=output_path

from os.path import join
import matplotlib as mpl
from matplotlib import pylab as plt
import pandas as pd
import numpy as np
from collections import defaultdict
import itertools as it
from datetime import datetime
import networkx as nx
font='AR PL KaitiM Big5'
mpl.rcParams['font.sans-serif'] = font

from IPython.display import HTML
from markdown import markdown
import csv
# %matplotlib inline
#from mpld3 import enable_notebook, disable_notebook
#enable_notebook()
#mpl.rcParams['figure.figsize'] = 12, 9

import seaborn as sns
sns.set(font=font)
sns.set_context('poster')
size_poster = mpl.rcParams['figure.figsize']
mpl.rcParams['figure.figsize'] = 16, 12

def rendermd(markdown_str):
    if hasattr(markdown_str, '__iter__'):
        markdown_str = u''.join(markdown_str)
    return HTML(u"<p>{}</p>".format(markdown(markdown_str)))
    
class ListTable(list):
    """ Overridden list class which takes a 2-dimensional list of 
        the form [[1,2,3],[4,5,6]], and renders an HTML Table in 
        IPython Notebook. """
    
    def _repr_html_(self):
        html = [u"<table>"]
        for row in self:
            html.append(u"<tr>")
            
            for col in row:
                html.append(u"<td>{0}</td>".format(unicode(col)))
            
            html.append(u"</tr>")
        html.append(u"</table>")
        return u''.join(html)
    
def table_attr(s, border=1):
    return s.replace(u'<table>',u'<table border="{0}">'.format(border))

def html_template(htmlstr,**kwargs):
    return u"""<!DOCTYPE: html>
<meta charset="utf-8"><style>
table {{
    border-collapse: collapse;
}}
td {{
    padding: 5px;
}}
table,th,td
{{
border:1px solid black;
}}
</style>
<html>
    <body>
        {0}
    </body>
</html>""".format(u''.join(map(unicode,htmlstr)))

def writehtml(li, fi):
    with open(fi, 'wb') as f:
        f.write(html_template(ListTable(li)._repr_html_()).encode('utf8'))
    
def writecsv(li, fi):
    with open(fi, 'wb') as csvfile:
        csvwriter = csv.writer(csvfile, delimiter=',',
                               quotechar='"', quoting=csv.QUOTE_MINIMAL)
        for r in li:
            csvwriter.writerow(map(lambda x:unicode(x).encode('utf8'),r))

def htmlcsv(msg, df, fi):
    html_url = u"{0}/html/{1}.html".format(output_path, fi)
    csv_url = u"{0}/csv/{1}.csv".format(output_path, fi)
    writehtml(df, html_url)
    writecsv(df, csv_url)
    markdown_str=u"{0}：[HTML]({1}), [CSV]({2})".format(msg, html_url, csv_url)
    return HTML(u"{}</p>".format(markdown(markdown_str)))

def write_d3(fi, dir, **kwargs):
    """
    Export d3 file, return htmrul
    """
    fi1=fi.replace('json', 'html')
    htmlfi = os.path.join(output_path, dir, fi1)
    htmlurl = os.path.join(urlpath, dir, fi1)

    render_html(htmlfi, FileName=fi, **kwargs)
    return unicode(htmlurl)

# %%
def hideaxis(pos=None):
    if pos:
        df=pd.DataFrame(pos.values(), columns=['x','y'])
        plt.xlim([df['x'].min()-5, df['x'].max()+5])
        plt.ylim([df['y'].min()-5, df['y'].max()+5])
    plt.gca().xaxis.set_major_locator(plt.NullLocator())
    plt.gca().yaxis.set_major_locator(plt.NullLocator())

    
def getcentral(g1):
    return pd.DataFrame({
      u'anc': {x:len(nx.ancestors(g1, x)) for x in g1.nodes()},
      u'des': {x:len(nx.descendants(g1, x)) for x in g1.nodes()},
      u'indeg': g1.in_degree(),
      u'outdeg': g1.out_degree()
      })


def printdf(s, coldic=None):
    x = ListTable()
    cols = []
    for k in s.columns:
        if coldic and k in coldic:
            cols.append(coldic[k])
        else:
            cols.append(k)            
    x.append(cols)
            
    for k, r in s.iterrows():
        x.append(r.values)
    return x

def defaultsize():
    disable_notebook()
    mpl.rcParams['figure.figsize'] = 12.8, 8.8
#enable_notebook()

def draw(g, ids, axishide=True, **kwargs):
    iddic = {k:fixname(getname(k)) for k in it.ifilter(lambda x:x in ids, g.nodes())}
    node_color = map(lambda k:k[1].get('group',0), g.node.iteritems())
    pos = nx.graphviz_layout(g)
    vmax = kwargs.get('vmax', max(node_color))
    node_size = kwargs.get('node_size', 40)
    cmap = kwargs.get('cmap', plt.cm.jet)
    
    nx.draw_networkx_edges(g, pos,
                     with_labels=False,
                     alpha=0.5,
                     edge_width=0.5,
                     edge_color='y',
                     )
    nx.draw_networkx_nodes(g, pos,
                     alpha=0.5,
                     node_color=node_color,
                     vmin=0,
                     vmax=vmax,
                     cmap=cmap,
                     node_size=node_size,
                     )
    nx.draw_networkx_labels(g, pos,
                            labels=iddic)
    if axishide:
        hideaxis(pos)

# %%
execfile('query.py')
from output import *
cn=init()

# %%
badnames = bad_board(cn)

dic = {}
for r in cn.boards.find({'name': {'$nin': badnames}}, {'_id':0, 'name':1, 'repr_inst':1}):
    if r['name'] not in dic:
        dic[r['name']] = [0,0]
    ret = dic[r['name']]
    ret[0] += 1
    if r['repr_inst'] <> '':
        ret[1] +=1

df = pd.DataFrame(dic.values(), columns=['cnt','rcnt'], index=dic.keys())
df['name'] = df.index
coldic = {'name': u'姓名', 'cnt': u'個數', 'rcnt': u'法人代表個數'}
df.sort('cnt', ascending=False, inplace=True)
#df.index = range(1, len(df)+1)

# %% [markdown]
# ## 如何辨別同名同姓的董監事？
#
# 本文將說明在 [台灣公司關係圖](http://gcis.nat.g0v.tw/) 的董監事資料中存在同名同姓的問題。董監事名單不像公司一樣有統一編號可供查詢，所以在比對不同公司董監事資料時，不可避免地會遇到同名同姓的問題。本文根據法人代表資料並結合不同公司間的相同董監事名單，協助分類同名同姓者。並以此分類結果作為尋找家族企業的基準。這篇文章僅為學術研究，模型正確性尚無有效評估方法，故分類結果僅供參考，不代表任何立場。
#
# 以下將先描述同名同姓可能的問題及影響，接下來作分類規則說明，最後是初步分析分類結果。

# %% [markdown]
# ## 同名同姓有多少？
#
# 關於同名同姓者這件事，應該要先從董監事姓名大排行談起。以下為最常出現的董監事姓名前 25 名：

# %%
printdf(df[['name','cnt']].head(25), coldic)
# Out:
# [[u'\u59d3\u540d', u'\u500b\u6578'],
#  array([u'\u9673\u6dd1\u82ac', 284], dtype=object),
#  array([u'\u9673\u5efa\u5b8f', 270], dtype=object),
#  array([u'\u9673\u4fca\u5b8f', 246], dtype=object),
#  array([u'\u9673\u7f8e\u73b2', 243], dtype=object),
#  array([u'\u6797\u6dd1\u60e0', 240], dtype=object),
#  array([u'\u9673\u6021\u541b', 239], dtype=object),
#  array([u'\u9673\u6dd1\u60e0', 238], dtype=object),
#  array([u'\u9673\u6dd1\u8c9e', 237], dtype=object),
#  array([u'\u9673\u7f8e\u60e0', 230], dtype=object),
#  array([u'\u9673\u9e97\u83ef', 214], dtype=object),
#  array([u'\u9673\u6dd1\u5a1f', 203], dtype=object),
#  array([u'\u6797\u5fd7\u660e', 195], dtype=object),
#  array([u'\u9673\u6dd1\u73b2', 189], dtype=object),
#  array([u'\u9ec3\u6dd1\u82ac', 184], dtype=object),
#  array([u'\u9673\u4fca\u826f', 179], dtype=object),
#  array([u'\u6797\u6dd1\u82ac', 177], dtype=object),
#  array([u'\u9673\u5fd7\u660e', 170], dtype=object),
#  array([u'\u9673\u6dd1\u83ef', 170], dtype=object),
#  array([u'\u9673\u5efa\u5fd7', 166], dtype=object),
#  array([u'\u6797\u4fca\u5b8f', 165], dtype=object),
#  array([u'\u6797\u6021\u541b', 162], dtype=object),
#  array([u'\u6797\u5efa\u5b8f', 162], dtype=object),
#  array([u'\u6797\u6dd1\u83ef', 159], dtype=object),
#  array([u'\u9673\u79c0\u7f8e', 157], dtype=object),
#  array([u'\u9673\u6dd1\u7f8e', 155], dtype=object)]

# %%
s = printdf(df[['name','cnt']].head(500), coldic)
htmlcsv(u'前五百大詳細內容見此', s, fi='name_rank')
# Out:
# <p>前五百大詳細內容見此：<a href="output/html/name_rank.html">HTML</a>, <a href="output/csv/name_rank.csv">CSV</a></p></p>

# %% [markdown]
# 由上表可發現這幾乎是菜市場名大排行，尤其有的姓名者有上百個以上，我們實在無法確認這些人剛好都同一人。
#
# 但我們可以進一步去觀察，在那些擔任法人代表的姓名中，最常出現的名字有哪些？以下是前 25 名的排行：

# %%
df.sort('rcnt', ascending=False, inplace=True)
s=df[['name','cnt','rcnt']]
printdf(s.head(25), coldic)
# Out:
# [[u'\u59d3\u540d', u'\u500b\u6578', u'\u6cd5\u4eba\u4ee3\u8868\u500b\u6578'],
#  array([u'\u9673\u570b\u69ae', 102, 51], dtype=object),
#  array([u'\u7f85\u667a\u5148', 50, 47], dtype=object),
#  array([u'\u56b4\u51f1\u6cf0', 49, 43], dtype=object),
#  array([u'\u8a31\u570b\u8208', 51, 41], dtype=object),
#  array([ u'\u4e2d\u83ef\u958b\u767c\u5de5\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         40, 39], dtype=object),
#  array([u'\u5433\u6771\u6607', 64, 39], dtype=object),
#  array([u'\u856d\u660e\u8f1d', 78, 37], dtype=object),
#  array([u'\u5f35\u5929\u5409', 45, 35], dtype=object),
#  array([u'\u9673\u5fd7\u9d3b', 89, 34], dtype=object),
#  array([u'\u9673\u5289\u60e0\u923a', 112, 34], dtype=object),
#  array([u'\u8521\u7d39\u4e2d', 46, 33], dtype=object),
#  array([u'\u6797\u5764\u714c', 57, 32], dtype=object),
#  array([u'\u5f90\u862d\u82f1', 42, 32], dtype=object),
#  array([u'\u9673\u5efa\u5fd7', 166, 32], dtype=object),
#  array([u'\u7df4\u53f0\u751f', 46, 32], dtype=object),
#  array([u'\u5f90\u65ed\u6771', 45, 31], dtype=object),
#  array([u'\u6bb7\u5efa\u79ae', 36, 31], dtype=object),
#  array([u'\u4f55\u58fd\u5ddd', 44, 31], dtype=object),
#  array([u'\u738b\u6587\u6df5', 43, 30], dtype=object),
#  array([u'\u621a\u7dad\u529f', 42, 30], dtype=object),
#  array([u'\u9673\u570b\u5e73', 52, 30], dtype=object),
#  array([u'\u9ec3\u666f\u8070', 38, 30], dtype=object),
#  array([u'\u6797\u4fca\u9f8d', 53, 29], dtype=object),
#  array([u'\u7f85\u5bb6\u6176', 34, 29], dtype=object),
#  array([ u'\u5146\u8c50\u570b\u969b\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         30, 29], dtype=object)]

# %%
s=printdf(df.head(500), coldic)
htmlcsv(u'前五百大詳細內容見此', s, fi='namer_rank')
# Out:
# <p>前五百大詳細內容見此：<a href="output/html/namer_rank.html">HTML</a>, <a href="output/csv/namer_rank.csv">CSV</a></p></p>

# %% [markdown]
# 上表中最多法人代表身份的姓名僅有 51 間公司，這與董監事姓名排行前 25 名中動輒一兩百個有很大差異。
# 而且出現許多熟知的集團老闆名字，故可推論法人代表會是一個好的參考依據。
# 不同公司的法人代表未必都是同一人，但若兩間公司之間存在法人投資關係則可視為同一人。
#
# 例如 A 公司與 B 公司存在法人投資關係，A 公司的某甲以法人代表身份出任 B 公司的董事，那麼 A 公司的某甲必然等於 B 公司的某甲。
# 如此即可藉由法人投資關係歸類部份的同名同姓者。

# %% [markdown]
# 接著思考兩兩公司間重複名字個數的多寡。若兩公司出現一個相同姓名的董監事，則其很有可能為同名同姓。但若同時出現兩個、甚至三個以上相同的董監事姓名，則這兩間公司很有可能是同一群人經營。且台灣的財團企業多以家族團體形式經營，故常見同一集團下的關係企業由同一群人擔任董監事的現象。計算重複兩個以上董監事的公司對，可繪製分配圖如下表：

# %%
dic=defaultdict(int)
for r in cn.grpconn.find():
    key = (r['com1'], r['com2'])
    dic[key] += 1
dic = pd.DataFrame(pd.Series(dic), columns=['cnt'])
dic['com1'], dic['com2'] = zip(*dic.index)
dic=dic.sort('cnt', ascending=False)
dic.index=range(len(dic))

coms = set(dic['com1'])
coms.update(dic['com2'])
namedic = {k:getname(k) for k in coms}
dic['name1'] = [namedic[k] for k in dic['com1']]
dic['name2'] = [namedic[k] for k in dic['com2']]

# %%
s=dic['cnt'].value_counts()
li=ListTable()
li.append([u'重複名字個數', u'發生次數'])
map(li.append, s.iteritems())
#li
s.plot(kind='bar', log=True)
plt.xlabel(u'重複名字個數')
_=plt.ylabel(u'發生次數')

# %% [markdown]
# 大部分公司對僅有兩個名字重複，某些公司對名字甚至會重複到 10 個以上。基本上若名字重複越多者，越容易相信該公司對的同名同姓者為同一群人。
# 以下為重複最多名字的公司對名單：

# %%
coldic = {'name1': u'公司一', 'name2': u'公司二', 'cnt': u'董監事重複個數'}
printdf(dic[['name1','name2','cnt']].head(25), coldic)
# Out:
# [[u'\u516c\u53f8\u4e00',
#   u'\u516c\u53f8\u4e8c',
#   u'\u8463\u76e3\u4e8b\u91cd\u8907\u500b\u6578'],
#  array([ u'\u83ef\u5357\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u83ef\u5357\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         32], dtype=object),
#  array([ u'\u5146\u8c50\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u5146\u8c50\u570b\u969b\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         28], dtype=object),
#  array([ u'\u5408\u4f5c\u91d1\u5eab\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u5408\u4f5c\u91d1\u5eab\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         24], dtype=object),
#  array([ u'\u60a0\u904a\u5361\u6295\u8cc7\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u60a0\u904a\u5361\u80a1\u4efd\u6709\u9650\u516c\u53f8', 24], dtype=object),
#  array([ u'\u654f\u76db\u8cc7\u7522\u7ba1\u7406\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u654f\u76db\u91ab\u63a7\u80a1\u4efd\u6709\u9650\u516c\u53f8', 23], dtype=object),
#  array([ u'\u7b2c\u4e00\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u7b2c\u4e00\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         23], dtype=object),
#  array([u'\u5de8\u57ce\u6295\u8cc7\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u897f\u5317\u5be6\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8', 23], dtype=object),
#  array([u'\u548c\u88d5\u6295\u8cc7\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u548c\u6cf0\u6c7d\u8eca\u80a1\u4efd\u6709\u9650\u516c\u53f8', 22], dtype=object),
#  array([ u'\u65b0\u5149\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u65b0\u5149\u4eba\u58fd\u4fdd\u96aa\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         22], dtype=object),
#  array([u'\u806f\u5104\u8cbf\u6613\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u4e09\u6cf0\u5316\u5de5\u539f\u6599\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         20], dtype=object),
#  array([u'\u9f8d\u79c0\u8208\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u89c0\u81ea\u5728\u8208\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         20], dtype=object),
#  array([u'\u806f\u5104\u8cbf\u6613\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u4e09\u5fb7\u4f01\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8', 20], dtype=object),
#  array([ u'\u570b\u6cf0\u4eba\u58fd\u4fdd\u96aa\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u570b\u6cf0\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         20], dtype=object),
#  array([ u'\u4e09\u6cf0\u5316\u5de5\u539f\u6599\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u4e09\u5fb7\u4f01\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8', 20], dtype=object),
#  array([ u'\u5bcc\u90a6\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u53f0\u5317\u5bcc\u90a6\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         20], dtype=object),
#  array([u'\u7d71\u4e00\u8d85\u5546\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u7d71\u4e00\u4f01\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8', 19], dtype=object),
#  array([ u'\u570b\u6cf0\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u570b\u6cf0\u4e16\u83ef\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         19], dtype=object),
#  array([ u'\u6d77\u5916\u53f0\u5546\u570b\u969b\u958b\u767c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u6d77\u5916\u53f0\u5546\u65c5\u884c\u793e\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         19], dtype=object),
#  array([ u'\u53f0\u65b0\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u53f0\u65b0\u570b\u969b\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         18], dtype=object),
#  array([ u'\u83ef\u5357\u91d1\u878d\u63a7\u80a1\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u83ef\u5357\u7522\u7269\u4fdd\u96aa\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         18], dtype=object),
#  array([u'\u54c1\u51a0\u884c\u92b7\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u5473\u4e39\u4f01\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8', 18], dtype=object),
#  array([ u'\u6843\u5712\u6c7d\u8eca\u5ba2\u904b\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u6843\u5ba2\u8cc7\u7522\u958b\u767c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         18], dtype=object),
#  array([u'\u8ca1\u6210\u4f01\u696d\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u5efa\u6210\u958b\u767c\u80a1\u4efd\u6709\u9650\u516c\u53f8', 18], dtype=object),
#  array([ u'\u8cc7\u8aa0\u7a05\u52d9\u8aee\u8a62\u9867\u554f\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u8cc7\u8aa0\u4f01\u696d\u7ba1\u7406\u9867\u554f\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         18], dtype=object),
#  array([u'\u9060\u6771\u65b0\u4e16\u7d00\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         u'\u4e9e\u6d32\u6c34\u6ce5\u80a1\u4efd\u6709\u9650\u516c\u53f8', 17], dtype=object)]

# %% [markdown]
# ## 分類規則說明
#
# 結合法人代表與同名同姓重複個數的資訊，我們可以設計以下的分類流程：
#
# 1. 列出所有姓名名單。
# 1. 給定一個名字某甲，找出所有該名字擔任董監事的公司，假設不同公司的某甲為不同人。
# 2. 根據法人代表名單進行初步分類，若某甲以 A 公司法人代表身份出任 B 公司董監事，則視 A 公司與 B 公司的某甲為同一人。
# 3. 根據不同的兩公司之間，有兩個以上董監事姓名重複、且包含某甲者，視這些名字為同一人。
# 4. 儲存分類結果進資料庫，回到步驟 2 處理下一個名字。

# %% [markdown]
# 根據以上分類結果，我們可以重新比較分類前後的董監事名單如下：

# %%
badnames = bad_board(cn)

dic = {}
for r in cn.boards.find({'name': {'$nin': badnames}}, {'_id':0, 'name':1, 'repr_inst':1}):
    if r['name'] not in dic:
        dic[r['name']] = [0,0]
    ret = dic[r['name']]
    ret[0] += 1
    if r['repr_inst'] <> '':
        ret[1] +=1

df = pd.DataFrame(dic.values(), columns=['cnt','rcnt'], index=dic.keys())
df['name'] = df.index
#printdf(df.sort('cnt', ascending=False, inplace=True), coldic)
df.sort('cnt', ascending=False, inplace=True)
#df.index = range(1, len(df)+1)

# %%
ret = cn.bossnode.find({}, ['name', 'target'])
dic = defaultdict(int)
for r in ret:
    dic[r['name']] += 1
dic = pd.Series(dic.values(), index=dic.keys())
#print dic.head()

# %%
#df1=df.copy()
df['grpcnt'] = dic
df['grpdiff'] = df['cnt'] - df['grpcnt']
df['diffr'] = df['grpdiff'] / df['cnt'] * 100
coldic = {'name': u'姓名',
          'cnt': u'個數',
          'rcnt': u'法人代表個數',
          'grpcnt': u'分類後組數',
          'grpdiff': u'減少組數',
          'diffr': u'減少比率'}
df1 = df.sort('diffr', ascending=False).head(25)
df1['diffr'] = df1['diffr'].map(lambda x:round(x,2))
printdf(df1[['name','cnt','rcnt','grpcnt','grpdiff','diffr']], coldic)
#df.head()
# Out:
# [[u'\u59d3\u540d',
#   u'\u500b\u6578',
#   u'\u6cd5\u4eba\u4ee3\u8868\u500b\u6578',
#   u'\u5206\u985e\u5f8c\u7d44\u6578',
#   u'\u6e1b\u5c11\u7d44\u6578',
#   u'\u6e1b\u5c11\u6bd4\u7387'],
#  array([u'\u56b4\u51f1\u6cf0', 49, 43, 1, 48, 97.96], dtype=object),
#  array([u'\u5433\u6771\u9032', 47, 27, 1, 46, 97.87], dtype=object),
#  array([u'\u8521\u7d39\u4e2d', 46, 33, 1, 45, 97.83], dtype=object),
#  array([u'\u5f35\u5929\u5409', 45, 35, 1, 44, 97.78], dtype=object),
#  array([u'\u5f90\u65ed\u6771', 45, 31, 1, 44, 97.78], dtype=object),
#  array([ u'\u4e2d\u83ef\u958b\u767c\u5de5\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         40, 39, 1, 39, 97.5], dtype=object),
#  array([u'\u8521\u6167\u502b', 38, 28, 1, 37, 97.37], dtype=object),
#  array([u'\u9ec3\u666f\u8070', 38, 30, 1, 37, 97.37], dtype=object),
#  array([u'\u9673\u5289\u60e0\u923a', 112, 34, 3, 109, 97.32], dtype=object),
#  array([u'\u5f35\u9673\u746a\u84ee', 111, 5, 3, 108, 97.3], dtype=object),
#  array([u'\u6797\u7fa9\u5b88', 36, 24, 1, 35, 97.22], dtype=object),
#  array([u'\u856d\u6c7e\u68af', 35, 15, 1, 34, 97.14], dtype=object),
#  array([u'\u6797\u5b5d\u81fb', 33, 22, 1, 32, 96.97], dtype=object),
#  array([u'\u8881\u6587\u8335', 31, 17, 1, 30, 96.77], dtype=object),
#  array([ u'\u5146\u8c50\u570b\u969b\u5546\u696d\u9280\u884c\u80a1\u4efd\u6709\u9650\u516c\u53f8',
#         30, 29, 1, 29, 96.67], dtype=object),
#  array([u'\u6797\u9d3b\u582f', 28, 2, 1, 27, 96.43], dtype=object),
#  array([u'\u8b1d\u9f8d\u8cdc', 28, 0, 1, 27, 96.43], dtype=object),
#  array([u'\u82d7\u8c50\u5f37', 27, 18, 1, 26, 96.3], dtype=object),
#  array([u'\u8b1d\u9f8d\u96b1', 27, 0, 1, 26, 96.3], dtype=object),
#  array([u'\u5442\u8c6b\u6587', 27, 19, 1, 26, 96.3], dtype=object),
#  array([u'\u8b1d\u9f8d\u8d0a', 26, 0, 1, 25, 96.15], dtype=object),
#  array([u'\u838a\u81ea\u7acb', 26, 7, 1, 25, 96.15], dtype=object),
#  array([u'\u5f35\u6cd3\u6c60', 26, 15, 1, 25, 96.15], dtype=object),
#  array([u'\u8449\u714c\u8ca1', 26, 21, 1, 25, 96.15], dtype=object),
#  array([u'\u8521\u65fa\u5bb6', 26, 20, 1, 25, 96.15], dtype=object)]

# %% [markdown]
# 對於某些名字，特別是集團老闆的名字而言，分類後數量大幅減少。但也不是每個名字都相應減少，從下面名字次數分配與分類後的次數分配圖觀察可知，右尾分配在分類後大幅減少，但左尾並無相應的減少。

# %%
s0=df['cnt'].value_counts()
s1=df['grpcnt'].value_counts()

fig, ax = plt.subplots(1)
ax.set_yscale('log')
ax.plot(s0.index, s0.values, 'b.')
_=ax.plot(s1.index, s1.values, 'r.')

# %% [markdown]
# 經過以上分類程序後，我們可以初步對董監事名單作分類，甚至可以針對分類後姓名，利用社會網路分析找出其代表之公司。例如謝國樑：

# %%
def get_coms_boss(names, maxlvl=1):
    if not hasattr(names, '__iter__'):
        names = [names]
    return cn.boards.find({'name': {'$in': names}}).distinct('id')

def get_network_boss(names):
    ids = get_coms_boss(name)
    g = get_network(ids, maxlvl=1)
    
    n=0
    for r in cn.bossnode.find({'name': name}):
        key = r['name'], r['target']
        n += 1
        for id in r['coms']:
            if id in g.node:
                g.node[id]['group'] = n
    
    for k, v in g.node.iteritems():
        if 'group' not in v:
            v['group'] = 0    
    return g, ids
    
name = u'謝國樑'
g, ids = get_network_boss(name)
draw(g, ids, node_size=100)
for k1, k1dic in g.edge.iteritems():
    for k2, dic in k1dic.iteritems():
        condic = {'src': k1,
                  'dst': k2}
        ret = cn.comivst.find(condic)
        for r in ret:
            dic['weight'] = r['seatratio']/10

fi = 'samename.shie.json'
exp_company(g, jsonfi=join(output_path, 'html', fi))
html_url=write_d3(fi, 'html', color='category10')

markdown_str=u"[另開新頁]({0})".format(unicode(html_url))
HTML(markdown(markdown_str)) #+\
#     u'<iframe height="600px" width="100%" src={0}></iframe>'.format(html_url))
# Out:
# <p><a href="output/html/samename.shie.html">另開新頁</a></p>

# %% [markdown]
# 上圖中橘色企業為經模型分類後，認定為同一個謝國樑擔任董監事的企業。其他顏色企業，除了深藍色以外，皆被模型認定為不同的謝國樑。其中謝林興業並不與其他橘色企業存在投資關係，但其董監事成員中有四人與大魯閣纖維完全重複，故被認定為同一群人經營之企業。
#
# 另外以王雪紅為例：

# %%
name = u'王雪紅'
g, ids = get_network_boss(name)
draw(g, ids, node_size=100)
for k1, k1dic in g.edge.iteritems():
    for k2, dic in k1dic.iteritems():
        condic = {'src': k1,
                  'dst': k2}
        ret = cn.comivst.find(condic)
        for r in ret:
            dic['weight'] = r['seatratio']/10

fi = 'samename.shie.json'
exp_company(g, jsonfi=join(output_path, 'html', fi))
html_url=write_d3(fi, 'html', color='category10')

markdown_str=u"[另開新頁]({0})".format(unicode(html_url))
HTML(markdown(markdown_str)) #+\
#     u'<iframe height="600px" width="100%" src={0}></iframe>'.format(html_url))
# Out:
# <p><a href="output/html/samename.shie.html">另開新頁</a></p>

# %% [markdown]
# 王雪紅擔任不少公司，其中也包含宏達電、台塑等公司的董監事。但就模型分類結果而言，宏達國際電池與威創科技顧問等公司亦被模型認定為同一個王雪紅經營。而聯宏育樂與聯宏建設開發則被模型認定為另一個王雪紅所經營。如此即可降低集團分類時的困難度。

# %% [markdown]
# ## 結語
#
# 本文提供了一種基於法人代表與重複董監事名單資訊而建立的分類模型，可協助降低分辨同名同姓董監事的複雜度。藉由有效的分類董監事模型，可幫助我們判斷同一人或同一群人經營的集團企業，而不會僅限制於交叉投資關係。

# %%
HTML(html)
# Out:
# <small>
# <p> This post was written as an IPython notebook.  It is available for
# <a href="http://WeiChengLiou.github.com/blog/downloads/
# notebooks/2014-08-03-first_post.ipynb">download</a>.</p>
# <p></p>
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img
# alt="Creative Commons License" style="border-width:0"
# src="http://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /><span
# xmlns:dct="http://purl.org/dc/terms/"
# property="dct:title">Gilbert's Data Lab</span> by <a
# xmlns:cc="http://creativecommons.org/ns#" href="http://WeiChengLiou.github.io/"
# property="cc:attributionName" rel="cc:attributionURL">WeiCheng Liou</a> is
# licensed under a <a rel="license"
# href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons
# Attribution-ShareAlike 4.0 International License</a>.<br />Based on a work at <a
# xmlns:dct="http://purl.org/dc/terms/" href="http://WeiChengLiou.github.io/"
# rel="dct:source">http://WeiChengLiou.github.io/</a>.

# %%
HTML(hidecode)
# Out:
# <script type="text/javascript">
# function hideElements(elements, start) {
#     for(var i = 0, length = elements.length; i < length;i++) {
#         if(i >= start) {
#             elements[i].style.display = "none";
#         }
#     }
# }
# var input_elements = document.getElementsByClassName('input');
# hideElements(input_elements, 0);
# var prompt_elements = document.getElementsByClassName('prompt');
# hideElements(prompt_elements, 0);
# </script>
